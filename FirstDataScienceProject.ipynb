# %%
import pandas as pd
import os

# %%
# !mkdir data

# %%
files=[file for file in os.listdir('data')]
all_months_data=pd.DataFrame()
for file in files:
  df=pd.read_csv('./data/'+file)
  all_months_data=pd.concat([all_months_data,df])
all_months_data.to_csv('all_data.csv',index=False)
all_data = pd.read_csv('all_data.csv')
all_data.tail()
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 161728   162004  Apple Airpods Headphones                1        150
# 161729   162005    AAA Batteries (4-pack)                2       2.99
# 161730   162006      USB-C Charging Cable                1      11.95
# 161731   162007      USB-C Charging Cable                1      11.95
# 161732   162008          27in FHD Monitor                1     149.99
#
#             Order Date                         Purchase Address
# 161728  02/12/19 22:02   227 Church St, San Francisco, CA 94016
# 161729  02/04/19 20:44  417 Jefferson St, Los Angeles, CA 90001
# 161730  02/24/19 06:31            498 8th St, Atlanta, GA 30301
# 161731  02/24/19 19:09             715 7th St, Dallas, TX 75001
# 161732  02/26/19 17:15       677 West St, Los Angeles, CA 90001

# %%
all_data.head(100)
# Out:
#    Order ID                     Product Quantity Ordered Price Each  \
# 0    222910    Apple Airpods Headphones                1        150
# 1    222911               Flatscreen TV                1        300
# 2    222912       AA Batteries (4-pack)                1       3.84
# 3    222913       AA Batteries (4-pack)                1       3.84
# 4    222914      AAA Batteries (4-pack)                5       2.99
# ..      ...                         ...              ...        ...
# 95   223005            27in FHD Monitor                1     149.99
# 96   223006    Lightning Charging Cable                1      14.95
# 97   223007  Bose SoundSport Headphones                1      99.99
# 98   223008      AAA Batteries (4-pack)                3       2.99
# 99   223009    Apple Airpods Headphones                1        150
#
#         Order Date                    Purchase Address Month
# 0   07/26/19 16:51     389 South St, Atlanta, GA 30301    07
# ...

# %%
##Drop NAN

# %%
nan_df=all_data[all_data.isna().any(axis=1)]
nan_df.head()
all_data=all_data.dropna(how='all')
all_data.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   222910  Apple Airpods Headphones                1        150
# 1   222911             Flatscreen TV                1        300
# 2   222912     AA Batteries (4-pack)                1       3.84
# 3   222913     AA Batteries (4-pack)                1       3.84
# 4   222914    AAA Batteries (4-pack)                5       2.99
#
#        Order Date                  Purchase Address
# 0  07/26/19 16:51   389 South St, Atlanta, GA 30301
# 1  07/05/19 08:55     590 4th St, Seattle, WA 98101
# 2  07/29/19 12:41    861 Hill St, Atlanta, GA 30301
# 3  07/28/19 10:15   190 Ridge St, Atlanta, GA 30301
# 4  07/31/19 02:13  824 Forest St, Seattle, WA 98101

# %%
nan1_df=all_data[all_data.isna().any(axis=1)]
nan1_df.head()
# Out:
# Empty DataFrame
# Columns: [Order ID, Product, Quantity Ordered, Price Each, Order Date, Purchase Address]
# Index: []

# %%
##Find 'or' and delete

# %%
all_data=all_data[all_data['Order Date'].str[0:2] !='Or']

# %%
####Question 1:What was the best month for sales?How much was earned?

# %%
all_data['Month']=all_data['Order Date'].str[0:2]
all_data['Month']=all_data['Month'].astype('int32')
all_data.head()
# Out:
#   Order ID                   Product Quantity Ordered Price Each  \
# 0   222910  Apple Airpods Headphones                1        150
# 1   222911             Flatscreen TV                1        300
# 2   222912     AA Batteries (4-pack)                1       3.84
# 3   222913     AA Batteries (4-pack)                1       3.84
# 4   222914    AAA Batteries (4-pack)                5       2.99
#
#        Order Date                  Purchase Address  Month
# 0  07/26/19 16:51   389 South St, Atlanta, GA 30301      7
# 1  07/05/19 08:55     590 4th St, Seattle, WA 98101      7
# 2  07/29/19 12:41    861 Hill St, Atlanta, GA 30301      7
# 3  07/28/19 10:15   190 Ridge St, Atlanta, GA 30301      7
# 4  07/31/19 02:13  824 Forest St, Seattle, WA 98101      7

# %%
##data cleaning

# %%
all_data['Quantity Ordered']=all_data['Quantity Ordered'].astype('int32')

all_data.head()
# Out:
#   Order ID                   Product  Quantity Ordered Price Each  \
# 0   222910  Apple Airpods Headphones                 1        150
# 1   222911             Flatscreen TV                 1        300
# 2   222912     AA Batteries (4-pack)                 1       3.84
# 3   222913     AA Batteries (4-pack)                 1       3.84
# 4   222914    AAA Batteries (4-pack)                 5       2.99
#
#        Order Date                  Purchase Address  Month
# 0  07/26/19 16:51   389 South St, Atlanta, GA 30301      7
# 1  07/05/19 08:55     590 4th St, Seattle, WA 98101      7
# 2  07/29/19 12:41    861 Hill St, Atlanta, GA 30301      7
# 3  07/28/19 10:15   190 Ridge St, Atlanta, GA 30301      7
# 4  07/31/19 02:13  824 Forest St, Seattle, WA 98101      7

# %%
all_data['Price Each']=all_data['Price Each'].astype('float')
all_data.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   222910  Apple Airpods Headphones                 1      150.00
# 1   222911             Flatscreen TV                 1      300.00
# 2   222912     AA Batteries (4-pack)                 1        3.84
# 3   222913     AA Batteries (4-pack)                 1        3.84
# 4   222914    AAA Batteries (4-pack)                 5        2.99
#
#        Order Date                  Purchase Address  Month
# 0  07/26/19 16:51   389 South St, Atlanta, GA 30301      7
# 1  07/05/19 08:55     590 4th St, Seattle, WA 98101      7
# 2  07/29/19 12:41    861 Hill St, Atlanta, GA 30301      7
# 3  07/28/19 10:15   190 Ridge St, Atlanta, GA 30301      7
# 4  07/31/19 02:13  824 Forest St, Seattle, WA 98101      7

# %%
all_data['Sales']=all_data['Quantity Ordered']*all_data['Price Each']
all_data.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   222910  Apple Airpods Headphones                 1      150.00
# 1   222911             Flatscreen TV                 1      300.00
# 2   222912     AA Batteries (4-pack)                 1        3.84
# 3   222913     AA Batteries (4-pack)                 1        3.84
# 4   222914    AAA Batteries (4-pack)                 5        2.99
#
#        Order Date                  Purchase Address  Month   Sales
# 0  07/26/19 16:51   389 South St, Atlanta, GA 30301      7  150.00
# 1  07/05/19 08:55     590 4th St, Seattle, WA 98101      7  300.00
# 2  07/29/19 12:41    861 Hill St, Atlanta, GA 30301      7    3.84
# 3  07/28/19 10:15   190 Ridge St, Atlanta, GA 30301      7    3.84
# 4  07/31/19 02:13  824 Forest St, Seattle, WA 98101      7   14.95

# %%
results=all_data.groupby('Month').sum()
# Out:
# <ipython-input-52-99f4475d62eb>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   results=all_data.groupby('Month').sum()

# %%
import matplotlib.pyplot as plt
months=range(1,13)
plt.bar(months,results['Sales'])
plt.xticks(months)
plt.xlabel('Sales in USD($)')
plt.ylabel('Months of Year')
plt.show()

# %%
##Which city had highest number of sales?

# %%
def get_city(address):
  return address.split(',')[1]
def get_state(address):
  return address.split(',')[2].split(' ')[1]
all_data['Cities']=all_data['Purchase Address'].apply(lambda x:get_city(x)+'('+get_state(x)+')')
all_data.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   222910  Apple Airpods Headphones                 1      150.00
# 1   222911             Flatscreen TV                 1      300.00
# 2   222912     AA Batteries (4-pack)                 1        3.84
# 3   222913     AA Batteries (4-pack)                 1        3.84
# 4   222914    AAA Batteries (4-pack)                 5        2.99
#
#        Order Date                  Purchase Address  Month   Sales  \
# 0  07/26/19 16:51   389 South St, Atlanta, GA 30301      7  150.00
# 1  07/05/19 08:55     590 4th St, Seattle, WA 98101      7  300.00
# 2  07/29/19 12:41    861 Hill St, Atlanta, GA 30301      7    3.84
# 3  07/28/19 10:15   190 Ridge St, Atlanta, GA 30301      7    3.84
# 4  07/31/19 02:13  824 Forest St, Seattle, WA 98101      7   14.95
#
#          Cities
# 0   Atlanta(GA)
# 1   Seattle(WA)
# 2   Atlanta(GA)
# 3   Atlanta(GA)
# 4   Seattle(WA)

# %%
results=all_data.groupby('Cities').sum()
results
# Out:
# <ipython-input-63-f0690b0f94e9>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   results=all_data.groupby('Cities').sum()
#                     Quantity Ordered  Price Each   Month       Sales
# Cities
#  Atlanta(GA)                   14378  2421201.13   80938  2434989.31
#  Austin(TX)                     9633  1576933.51   53651  1585304.68
#  Boston(MA)                    19499  3129588.22  108780  3150815.95
#  Dallas(TX)                    14430  2372746.27   80582  2385591.17
#  Los Angeles(CA)               28916  4742775.59  161608  4769107.88
#  New York City(NY)             24104  3990948.16  134955  4016679.92
#  Portland(ME)                   2398   395420.03   13364   397792.20
#  Portland(OR)                   9796  1609615.30   54647  1618835.15
# ...

# %%
import matplotlib.pyplot as plt
cities=list(all_data.groupby('Cities').groups.keys())
plt.bar(cities,results['Sales'],color='purple')
plt.xticks(cities,rotation='vertical',size=8)
plt.xlabel('Sales in USD($)')
plt.ylabel('Cities in US')
plt.show()

# %%
##At what time should we display advertisement to maximise likelihood of customer's buying product?

# %%
all_data.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   222910  Apple Airpods Headphones                 1      150.00
# 1   222911             Flatscreen TV                 1      300.00
# 2   222912     AA Batteries (4-pack)                 1        3.84
# 3   222913     AA Batteries (4-pack)                 1        3.84
# 4   222914    AAA Batteries (4-pack)                 5        2.99
#
#        Order Date                  Purchase Address  Month   Sales  \
# 0  07/26/19 16:51   389 South St, Atlanta, GA 30301      7  150.00
# 1  07/05/19 08:55     590 4th St, Seattle, WA 98101      7  300.00
# 2  07/29/19 12:41    861 Hill St, Atlanta, GA 30301      7    3.84
# 3  07/28/19 10:15   190 Ridge St, Atlanta, GA 30301      7    3.84
# 4  07/31/19 02:13  824 Forest St, Seattle, WA 98101      7   14.95
#
#          Cities
# 0   Atlanta(GA)
# 1   Seattle(WA)
# 2   Atlanta(GA)
# 3   Atlanta(GA)
# 4   Seattle(WA)

# %%
all_data['Hour']=pd.to_datetime(all_data['Order Date'])

# %%
all_data['Hour'] = pd.to_datetime(all_data['Order Date']).dt.hour
all_data['Minute']=pd.to_datetime(all_data['Order Date']).dt.minute
all_data.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   222910  Apple Airpods Headphones                 1      150.00
# 1   222911             Flatscreen TV                 1      300.00
# 2   222912     AA Batteries (4-pack)                 1        3.84
# 3   222913     AA Batteries (4-pack)                 1        3.84
# 4   222914    AAA Batteries (4-pack)                 5        2.99
#
#        Order Date                  Purchase Address  Month   Sales  \
# 0  07/26/19 16:51   389 South St, Atlanta, GA 30301      7  150.00
# 1  07/05/19 08:55     590 4th St, Seattle, WA 98101      7  300.00
# 2  07/29/19 12:41    861 Hill St, Atlanta, GA 30301      7    3.84
# 3  07/28/19 10:15   190 Ridge St, Atlanta, GA 30301      7    3.84
# 4  07/31/19 02:13  824 Forest St, Seattle, WA 98101      7   14.95
#
#          Cities  Hour  Minute
# 0   Atlanta(GA)    16      51
# 1   Seattle(WA)     8      55
# 2   Atlanta(GA)    12      41
# 3   Atlanta(GA)    10      15
# ...

# %%
hours = list(all_data.groupby('Hour').groups.keys())

plt.plot(hours,all_data.groupby(['Hour']).count(),color='red')
plt.xticks(hours)
plt.grid()
plt.xlabel('Hours')
plt.ylabel('Number of Order')
plt.show()

# %%
all_data.head()
# Out:
#   Order ID                   Product  Quantity Ordered  Price Each  \
# 0   222910  Apple Airpods Headphones                 1      150.00
# 1   222911             Flatscreen TV                 1      300.00
# 2   222912     AA Batteries (4-pack)                 1        3.84
# 3   222913     AA Batteries (4-pack)                 1        3.84
# 4   222914    AAA Batteries (4-pack)                 5        2.99
#
#        Order Date                  Purchase Address  Month   Sales  \
# 0  07/26/19 16:51   389 South St, Atlanta, GA 30301      7  150.00
# 1  07/05/19 08:55     590 4th St, Seattle, WA 98101      7  300.00
# 2  07/29/19 12:41    861 Hill St, Atlanta, GA 30301      7    3.84
# 3  07/28/19 10:15   190 Ridge St, Atlanta, GA 30301      7    3.84
# 4  07/31/19 02:13  824 Forest St, Seattle, WA 98101      7   14.95
#
#          Cities  Hour  Minute
# 0   Atlanta(GA)    16      51
# 1   Seattle(WA)     8      55
# 2   Atlanta(GA)    12      41
# 3   Atlanta(GA)    10      15
# ...

# %%
#Question 4:Which products are sold together?

# %%
df = all_data[all_data['Order ID'].duplicated(keep=False)]
df['Grouped']=df.groupby('Order ID')['Product'].transform(lambda x:','.join(x))
df=df[['Order ID','Grouped']].drop_duplicates()
df.head()
# Out:
# <ipython-input-121-c27cc45227b8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grouped']=df.groupby('Order ID')['Product'].transform(lambda x:','.join(x))
#     Order ID                                            Grouped
# 118   223028  Vareebadd Phone,USB-C Charging Cable,Wired Hea...
# 140   223048               Vareebadd Phone,USB-C Charging Cable
# 188   223095     Apple Airpods Headphones,AA Batteries (4-pack)
# 201   223106                   Wired Headphones,Vareebadd Phone
# 213   223117                  Google Phone,USB-C Charging Cable
